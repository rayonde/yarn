# %% [markdown]
# # PhilReinholdPygrape tutorial 2: State transfer
#
# This notebook is based on the original examples written by Phil,
# they can be found in [this directory](https://github.com/tesla-cat/yarn/tree/master/examplesFromForkedLibraries/PhilReinholdPygrape).
# Specifically, it contains the following:
#
# - `pi_pulse_state_transfer.py`
#
# Ruiqi, 27 Jun 2020

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from yarn.PhilReinholdPygrape import (
    run_grape, StateTransferSetup, plot, 
)
from yarn.qutipHelpers import (
    plotWigners, plotWignersIntermediateStates, 
    plotOccupations, plotOccupationsIntermediateStates,
    plotExpectation, cat
)

# %% [markdown]
# ## parameters

# %%
dim = 5
anharmonicity = 0.4

# %% [markdown]
# ## ladder operators

# %%
a = destroy(dim)
ad = a.dag()
numberOperator = ad * a

# %% [markdown]
# ## drift Hamiltonian

# %%
Hdrift = (anharmonicity/2) * ad * ad * a * a

# %% [markdown]
# ## control Hamiltonian

# %%
X =     a + ad
Y = 1j*(a - ad)
HcontrolList = [X, Y]

# %% [markdown]
# ## initial and target states
#
# Pauli-X gate

# %%
initStates = [fock(dim, 0), fock(dim, 1)]
targetStates = [fock(dim, 1), fock(dim, 0)]

# %% [markdown]
# cat state

# %%
#initStates = [fock(dim, 0)]
#targetStates = [cat(dim, 1)]

# %% [markdown]
# ## define the grape setup

# %%
setup = StateTransferSetup(
    Hdrift, HcontrolList, initStates, targetStates
)

# %% [markdown]
# ## define the initial control sequence

# %%
initControls = 1e-3 * np.ones((len(HcontrolList), 200))

# %% [markdown]
# ## define filter function
#
# the filter function generates the response versus frequency,
# we will use a 4th order **0.3 GHz** Butterworth low-pass filter

# %%
filt_func = lambda f: 1 / np.sqrt(1 + (f / .3)**8)

# %% [markdown]
# ## constrain the shape
#
# `shape_sigma` specifies the width of the shape function,
# which forces the amplitude to go to zero smoothly at the beginning and end of the pulse

# %%
shape_sigma=1

# %% [markdown]
# ## run grape

# %%
import warnings; warnings.filterwarnings('ignore')

result = run_grape(
    initControls, setup,
    dt=0.2, #filt_func=filt_func, shape_sigma=shape_sigma,
)
# Out:
# 0 - Fids: 0.0377745 1 - Fids: 0.0377745 2 - Fids: 0.4058122 3 - Fids: 0.9954547 4 - Fids: 0.9995655 5 - Fids: 0.999835 6 - Fids: 0.9999099 7 - Fids: 0.9999571 8 - Fids: 0.9999901 9 - Fids: 0.9999916 10 - Fids: 0.9999922 11 - Fids: 0.9999939 12 - Fids: 0.9999964 13 - Fids: 0.9999991 14 - Fids: 0.9999985 15 - Fids: 0.9999994 16 - Fids: 0.9999999 17 - Fids: 0.9999999 18 - Fids: 1 19 - Fids: 1 20 - Fids: 1 21 - Fids: 1 22 - Fids: 1 23 - Fids: 1

# %% [markdown]
# ## plot

# %%
plot(result, ctrlNames=[r'$X=a+a^{\dagger}$',r'$Y=i(a-a^{\dagger})$'])

# %% [markdown]
# ## evaluate the resulting pulse using qutip

# %%
Ht = [list(a) for a in zip(HcontrolList, result.controls)]
Ht.append(Hdrift)
psi0 = initStates[0]
time = result.ts * 1.0

mesolveResult = mesolve(Ht,psi0,time,[],[])

# %% [markdown]
# ## plot `qutip.mesolve` results

# %%
observables = [{'Hdrift':Hdrift, 'numberOperator':numberOperator}]
plotExpectation(time,observables,mesolveResult)
plotWignersIntermediateStates(time,mesolveResult,number=6,radius=4)
plotOccupationsIntermediateStates(time,mesolveResult,number=6)
